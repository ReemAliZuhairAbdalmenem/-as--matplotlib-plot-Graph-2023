# %%
import matplotlib.pyplot as plt

# %%
dev_x = [22,23,25,26,35,35,36,55,43,33,33,45,58]

dev_y = [1000,2000,2500,3000,3500,4000,4500,
         5000,5500,6000,6500,7000,7500]

plt.plot(dev_x,dev_y)
